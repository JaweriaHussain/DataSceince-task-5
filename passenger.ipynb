# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
passenger = {'Year': [2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021],'Month': ['Jan','Feb','March', 'April','May','June','July','August','September','October','November','December'],'passengers':[2000,
1900,1400,1600,1750,1200,1000,1050,9000,950,2000,2400]}
df = pd.DataFrame(passenger)
sum= df['passengers'].sum()
print(f'total passengers in flights are: {sum}')
# max = df['passengers'].max()
# for i in range(len(df)):
#     if df['passengers'].max() == True:
#         print(df['Month',[i]])
# Out:
# total passengers in flights are: 26250

# %%
_passenger = pd.read_csv('dataset.csv')
Month = _passenger['Month']
passenger = _passenger['Passengers']
for i in range(len(_passenger)):
    if passenger == passenger.max():
        print(Month)

# %%
plt.plot(df)

# %%
passenger = {'Year': [2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021],'passengers':[2000,
1900,1400,1600,1750,1200,1000,1050,9000,950,2000,2400]}
df = pd.DataFrame(passenger)
heap = sns.heatmap(df)
